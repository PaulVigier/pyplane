# %% [markdown]
# # Tower fly-by
#
# ### 1. Data extraction

# %%
import pandas as pd
from libs import tower_fly_by

data=pd.read_csv(r"data/TFB/TFB_data.csv")
data=data.sort_values(by='Vic', ascending=True)
tower_fly_by.ADSC_computation(data, export=True)

###################################################################################################################
#Warning Graphs should be updated to better reflect Erb's requirement (no legend, lines labelled directly on the plots etc...)
# Out:
# CSV file generated in : data/TFB/Output.csv
