# %%
from libs import have_dream
from libs import das
from libs import constants as cst

#T-38 parameters
Sref=170*cst.FT_TO_M**2

flight=13

# %% [markdown]
# ## Sawtooth descent

# %%
if flight==1:
    ZFW=9185 #Tail 140
    data,event_list=das.das_read(r"data\Have dream\Flights\20250908_Dawson_140_HaveDream.csv",'T-38')
    sawtooth_times=[
                ['16:48:10','16:48:33',0,'Clean','A1 235kt'],
                ['16:50:39','16:51:05',0,'Clean','A1 235kt'],
                ['16:54:13','16:54:31',0,'Clean','A2 255kt'],
                ['16:56:17','16:56:39',0,'Clean','A2 255kt'],
                ['16:58:50','16:59:07',0,'Clean','A3 275kt'],
                ['17:00:50','17:01:13',0,'Clean','A3 275kt'],
                [13,14,0,'Clean','A4 295kt'],
                [15,16,0,'Clean','A4 295kt'],
                [17,18,0,'Clean','A5 315kt'],
                [19,20,0,'Clean','A5 315kt'],
                [24,25,0,'SB','B1 180kt'],
                [26,27,0,'SB','B1 180kt'],
                [28,29,0,'SB','B2 200kt'],
                [30,31,0,'SB','B2 200kt'],
                  ]
elif flight==2:
    ZFW=9185 #Tail 140
    data,event_list=das.das_read(r"data\Have dream\Flights\20250908_Vigier_140_HaveDream2.csv",'T-38')
    sawtooth_times=[
                [2,3,0,'Shuttle','C1 180kt'],
                [6,7,0,'Shuttle','C1 180kt'],
                [4,5,0,'Shuttle','C2 220kt'],
                [8,9,0,'Shuttle','C2 220kt'],
                [10,11,0,'Shuttle','C3 240kt'],
                [12,13,0,'Shuttle','C3 240kt'],
                [14,15,0,'Shuttle','C4 275kt'],
                [16,17,0,'Shuttle','C4 275kt'],
                [18,19,0,'X-24','D1 180kt'],
                [20,21,0,'X-24','D1 180kt'],
                [22,23,0,'X-24','D2 220kt'],
                [24,25,0,'X-24','D2 220kt'],
                [35,36,0,'X-24','D2 220kt'],
                [26,27,0,'X-24','D3 240kt'],
                [28,29,0,'X-24','D3 240kt'],
                [30,31,0,'X-24','D4 275kt'],
                [33,34,0,'X-24','D4 275kt'],
                  ]
elif flight==3:
    ZFW=9185 #Tail 140
    data,event_list=das.das_read(r"data\Have dream\Flights\20250909_Vigier_140_HaveDream3.csv",'T-38')
    sawtooth_times=[
                [7,8,0,'SB','B3 220kt'],
                [9,10,0,'SB','B3 220kt'],
                [11,12,0,'SB','B4 240kt'],
                [13,14,0,'SB','B4 240kt'],
                [15,16,0,'SB','B5 260kt'],
                [17,18,0,'SB','B5 260kt'],
                [22,23,0,'SB','B1 180kt'],
                [24,25,0,'SB','B1 180kt'],
                  ]
elif flight==4:
    ZFW=9185 #Tail 140
    data,event_list=das.das_read(r"data\Have dream\Flights\20250909_Dawson_140_HaveDream4.csv",'T-38')
    sawtooth_times=[
                [14,15,0,'Shuttle','C3 240kt'],
                [17,18,0,'Shuttle','C3 240kt'],
                [21,22,0,'X-24','D3 240kt'],
                [23,24,0,'X-24','D3 240kt'],
                [25,26,0,'Shuttle','C1 180kt'],
                [27,28,0,'Shuttle','C1 180kt'],
                  ]
elif flight==5:
    ZFW=9185 #Tail 140
    data,event_list=das.das_read(r"data\Have dream\Flights\20250910_Dawson_140_HaveDream5.csv",'T-38')
    sawtooth_times=[
                [7,8,0,'SB','B4 240kt'],
                [9,10,0,'SB','B4 240kt'],
                [11,13,0,'Shuttle','C4 275kt'],
                [14,15,0,'Shuttle','C4 275kt'],
                  ]
elif flight==6:
    ZFW=9185 #Tail 140
    data,event_list=das.das_read(r"data\Have dream\Flights\20250910_Vigier_140_HaveDream6.csv",'T-38')
    sawtooth_times=[
                [2,3,0,'SB','B2 200kt'],
                [4,5,0,'SB','B2 200kt'],
                [6,7,0,'SB','B3 220kt'],
                [8,9,0,'SB','B3 220kt'],
                [10,11,0,'SB','B4 240kt'],
                [12,13,0,'SB','B4 240kt'],
                [14,15,0,'SB','B4 240kt'],
                [16,'21:28:05',0,'SB','B5 260kt'],
                ['21:30:59','21:31:12',0,'SB','B5 260kt'],
                [20,21,0,'Clean','A1 235kt'],
                [22,23,0,'Clean','A1 235kt'],
                [24,25,0,'Clean','A2 255kt'],
                [26,27,0,'Clean','A2 255kt'],
                [28,29,0,'Clean','A3 275kt'],
                [30,31,0,'Clean','A3 275kt'],
                [32,33,0,'Clean','A4 295kt'],
                [34,35,0,'Clean','A4 295kt'],
                ['21:47:55','21:48:04',0,'Clean','A5 315kt'],
                [37,38,0,'Clean','A5 315kt'],
                  ]
elif flight==7:
    ZFW=9114 #Tail 382
    data,event_list=das.das_read(r"data\Have dream\Flights\20250912_Dawson_382_HaveDream7.csv",'T-38')
    sawtooth_times=[
                [5,6,0,'Clean','A6 195kt'],
                [7,8,0,'Clean','A6 195kt'],
                [9,10,0,'Clean','A7 215kt'],
                [11,12,0,'Clean','A7 215kt'],
                  ]
elif flight==8:
    ZFW=9114 #Tail 382
    data,event_list=das.das_read(r"data\Have dream\Flights\20250912_Starski_382_HaveDream8.csv",'T-38')
    sawtooth_times=[
                [15,16,0,'Clean','A6 195kt'],
                [17,18,0,'Clean','A6 195kt'],
                [19,20,0,'Clean','A7 215kt'],
                [21,22,0,'Clean','A7 215kt'],
                [23,24,0,'Clean','A1 235kt'],
                [25,26,0,'Clean','A1 235kt'],
                [27,28,0,'Clean','A2 255kt'],
                [29,30,0,'Clean','A2 255kt'],
                  ]

# %%
if 'sawtooth_times' in locals() and sawtooth_times:
    have_dream.sawtooth_descent(data, event_list, sawtooth_times, ZFW, flight, smooth='200ms', graphs=True)

# %% [markdown]
# ## Incremental drag descent

# %%
if flight==3:
    ZFW=9185 #Tail 140
    data,event_list=das.das_read(r"data\Have dream\Flights\20250909_Vigier_140_HaveDream3.csv",'T-38')
    inc_drag_times=[
                ['16:30:37','16:31:04',0,'SB','F1'],
                ['16:37:50','16:38:24',0,'SB','F1'],
                ['16:41:23','16:41:49',0,'Shuttle','F2'],
                ['16:45:05','16:45:32',0,'Shuttle','F2'],
                  ]
elif flight==4:
    ZFW=9185 #Tail 140
    data,event_list=das.das_read(r"data\Have dream\Flights\20250909_Dawson_140_HaveDream4.csv",'T-38')
    inc_drag_times=[
                ['21:34:09','21:35:01',0,'SB','F1'],
                ['21:42:31','21:43:03',0,'SB','F1'],
                ['21:48:47','21:49:18',0,'Shuttle','F2'],
                ['21:52:55','21:53:23',0,'Shuttle','F2'],
                  ]
elif flight==5:
    ZFW=9185 #Tail 140
    data,event_list=das.das_read(r"data\Have dream\Flights\20250910_Dawson_140_HaveDream5.csv",'T-38')
    inc_drag_times=[
                ['17:10:02','17:10:31',0,'SB','F1'],
                ['17:13:13','17:13:45',0,'SB','F1'],
                ['17:16:48','17:17:05',0,'Shuttle','F2'],
                ['17:19:51','17:20:14',0,'Shuttle','F2'],
                  ]

if 'inc_drag_times' in locals():
    have_dream.incremental_drag(data, event_list, inc_drag_times, ZFW, Sref, flight, smooth='200ms', graphs=True)

# %% [markdown]
# ## Turns

# %%
if flight==7:
    ZFW=9114 #Tail 382
    data,event_list=das.das_read(r"data\Have dream\Flights\20250912_Dawson_382_HaveDream7.csv",'T-38')
    turn_times=[
                [29,30,30,30,'Clean','G1bis small turn MTSU'],
                [31,32,32,32,'Clean','G1bis small turn MTSU'],
                [33,34,34,34,'Clean','G2bis medium turn MTSU'],
                [35,36,36,36,'Clean','G2bis medium turn MTSU'],
                  ]
if flight==8:
    ZFW=9114 #Tail 382
    data,event_list=das.das_read(r"data\Have dream\Flights\20250912_Starski_382_HaveDream8.csv",'T-38')
    turn_times=[
                [6,7,7,8,'Clean','G1 small turn UNCC'],
                  ]

if flight==13:
    ZFW=9114 #Tail 382
    data,event_list=das.das_read(r"data\Have dream\Flights\20250917_Dawson_382_HaveDream13.csv",'T-38')
    turn_times=[
                [1,2,3,4,'Clean','G1 small turn UNCC'],
                [5,6,7,8,'Clean','G2 medium turn UNCC'],
                [9,10,11,12,'Clean','G3 large turn UNCC'],
                [13,14,15,16,'Clean','G4 Xlarge turn UNCC'],
                [17,18,18,18,'Clean','G3bis large turn MTSU'],
                [19,20,20,20,'Clean','G4bis Xlarge turn MTSU'],
                [21,22,23,24,'Clean','J1 small decelerated turn UNCC'],
                [26,28,29,30,'Clean','J2 medium decelerated turn UNCC'],
                [32,33,34,35,'Clean','J3 large decelerated turn UNCC'],
                [36,37,37,38,'Shuttle','H1 small turn UNCC'],
                [39,40,41,42,'Shuttle','H2 medium turn UNCC'],
                [43,44,44,45,'X-24','I1 small turn UNCC'],
                [46,47,47,48,'X-24','I2 medium turn UNCC'],
                  ]

if 'turn_times' in locals():
    have_dream.turn_3_steps(data, event_list, turn_times, ZFW, flight, smooth='200ms', graphs=True)
# Out:
#   Cell In[5], line 17
#     if flight=13:
#        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?
